# %%
# To ensure every chip has the same weight on the final loss function, we calculate the mean error rather than the sum. 
# Specifically, we calculate the mean loss only for the pixels where the mask equals 1. 
# This gives us a single average error value for that specific chip. 
# When PyTorch averages those single values across the entire batch, every chip has an equal voice, regardless of its transect length.

# %%
import torch
from torch.utils.data import Dataset

class SatvisionDataset(Dataset):
    def __init__(self, file_paths):
        self.file_paths = file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):

        
        # 1. Load the ABI/chip array 


        # load the (7, 512, 512, 16) ABI array and use a combination of NumPy's transpose and reshape functions to flatten it into your (112, 512, 512) input tensor X.


        
        # 2. Load the CloudSat/cloud_class array
        # 3. Load the CloudSat/abi_row and abi_column arrays 
        
        # 4. Initialize empty 512x512 grids for the target and the mask
        # 5. Populate the target grid and mask using the row/col indices

        # using the CloudSat/abi_row and CloudSat/abi_column variables, we can find where on the mask we need to put 1s to have the loss calculate correctly

        
        
        # return X_tensor, Y_tensor, mask_tensor
